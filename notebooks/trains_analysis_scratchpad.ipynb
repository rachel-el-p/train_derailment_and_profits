# %%
import pandas as pd
import io
import numpy as np
import matplotlib.pyplot as plt

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# require('tidyverse')
# Out:
# R[write to console]: Loading required package: tidyverse
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.0     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.1     ✔ tibble    3.1.8
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
accidents_df = pd.read_csv('class_one_accidents.csv')
accidents_df.head()
# Out:
#   Reporting Railroad Code           Reporting Railroad Name  Report Year  \
# 0                      NS  Norfolk Southern Railway Company         2022
# 1                     CSX                CSX Transportation         2017
# 2                      NS  Norfolk Southern Railway Company         2022
# 3                      UP    Union Pacific Railroad Company         2022
# 4                      UP    Union Pacific Railroad Company         2022
#
#    Accident Year  Accident Month Accident Type  \
# 0             22               7    Derailment
# 1             17              12    Derailment
# 2             22               7    Derailment
# 3             22               2    Derailment
# 4             22              11    Derailment
#
#                            railroad accident_year_and_month
# 0  Norfolk Southern Railway Company                    22 7
# 1                CSX Transportation                   17 12
# 2  Norfolk Southern Railway Company                    22 7
# 3    Union Pacific Railroad Company                    22 2
# 4    Union Pacific Railroad Company                   22 11

# %%
bnsf_df = accidents_df[accidents_df['railroad'] == 'BNSF Railway Company']
bnsf_df['tally'] = bnsf_df.groupby("accident_year_and_month")['Reporting Railroad Code'].transform('count')
bnsf_df = bnsf_df.drop_duplicates(subset=['accident_year_and_month', 'tally'])
bnsf_df
# Out:
#      Reporting Railroad Code Reporting Railroad Name  Report Year  \
# 11                      BNSF    BNSF Railway Company         2022
# 12                      BNSF    BNSF Railway Company         2017
# 13                      BNSF    BNSF Railway Company         2017
# 14                      BNSF    BNSF Railway Company         2017
# 16                      BNSF    BNSF Railway Company         2017
# ...                      ...                     ...          ...
# 4473                    BNSF    BNSF Railway Company         2018
# 4520                    BNSF    BNSF Railway Company         2018
# 4540                    BNSF    BNSF Railway Company         2018
# 4568                    BNSF    BNSF Railway Company         2018
# 4589                    BNSF    BNSF Railway Company         2018
#
#       Accident Year  Accident Month Accident Type              railroad  \
# 11               22               5    Derailment  BNSF Railway Company
# 12               17               3    Derailment  BNSF Railway Company
# 13               17               9    Derailment  BNSF Railway Company
# 14               17               8    Derailment  BNSF Railway Company
# 16               17               6    Derailment  BNSF Railway Company
# ...             ...             ...           ...                   ...
# 4473             18               3    Derailment  BNSF Railway Company
# 4520             18               7    Derailment  BNSF Railway Company
# 4540             18               9    Derailment  BNSF Railway Company
# 4568             18               8    Derailment  BNSF Railway Company
# 4589             18               5    Derailment  BNSF Railway Company
#
#      accident_year_and_month  tally
# 11                      22 5     16
# 12                      17 3     18
# 13                      17 9     15
# 14                      17 8     28
# 16                      17 6     24
# ...                      ...    ...
# 4473                    18 3     26
# 4520                    18 7     31
# 4540                    18 9     24
# 4568                    18 8     21
# 4589                    18 5     18
#
# [72 rows x 9 columns]

# %%
from datetime import datetime
bnsf_miles_traveled_data = pd.read_csv('bnsf_miles_traveled_data.csv')
bnsf_miles_traveled_data.head()
bnsf_miles_traveled_data['accident_year_and_month'] = bnsf_miles_traveled_data['Month of Combined Date'].apply(lambda x: datetime.strptime(x, '%B %Y').strftime('%y %m'))
bnsf_miles_traveled_data['accident_year_and_month'] = bnsf_miles_traveled_data['accident_year_and_month'].str.replace(r'\b0', '')
bnsf_miles_traveled_data.head()
# Out:
#    Display Year Month of Combined Date      Measure Names  Measure Values  \
# 0          2017          December 2017  Total Train Miles        15482144
# 1          2017          November 2017  Total Train Miles        15440507
# 2          2017           October 2017  Total Train Miles        15925185
# 3          2017         September 2017  Total Train Miles        14971635
# 4          2017            August 2017  Total Train Miles        15360649
#
#   accident_year_and_month
# 0                   17 12
# 1                   17 11
# 2                   17 10
# 3                    17 9
# 4                    17 8

# %%
merged_df_3 = bnsf_df.merge(bnsf_miles_traveled_data, left_on='accident_year_and_month', right_on='accident_year_and_month')
merged_df_3.head()
merged_df_3['Measure Values'] = merged_df_3['Measure Values'] / 1000000
merged_df_3.head()
merged_df_3['accidents_per_million_miles_traveled'] = merged_df_3['tally'] / merged_df_3['Measure Values']
merged_df_3.head()
len(merged_df_3)
# Out:
# 72

# %%
bnsf_df = merged_df_3

# %%
union_pacific_df = accidents_df[accidents_df['railroad'] == 'Union Pacific Railroad Company']
union_pacific_df['tally'] = union_pacific_df.groupby("accident_year_and_month")['Reporting Railroad Code'].transform('count')
union_pacific_df = union_pacific_df.drop_duplicates(subset=['accident_year_and_month', 'tally'])
union_pacific_df.head()
# Out:
#    Reporting Railroad Code         Reporting Railroad Name  Report Year  \
# 3                       UP  Union Pacific Railroad Company         2022
# 4                       UP  Union Pacific Railroad Company         2022
# 5                       UP  Union Pacific Railroad Company         2022
# 9                       UP  Union Pacific Railroad Company         2017
# 15                      UP  Union Pacific Railroad Company         2017
#
#     Accident Year  Accident Month Accident Type  \
# 3              22               2    Derailment
# 4              22              11    Derailment
# 5              22               1    Derailment
# 9              17               4    Derailment
# 15             17              11    Derailment
#
#                           railroad accident_year_and_month  tally
# 3   Union Pacific Railroad Company                    22 2     20
# 4   Union Pacific Railroad Company                   22 11     35
# 5   Union Pacific Railroad Company                    22 1     23
# 9   Union Pacific Railroad Company                    17 4     13
# 15  Union Pacific Railroad Company                   17 11     27

# %%
up_miles_traveled_data = pd.read_csv('/Users/rachelp/Downloads/up_miles_traveled.csv')
up_miles_traveled_data.head()
up_miles_traveled_data['accident_year_and_month'] = up_miles_traveled_data['Month of Combined Date'].apply(lambda x: datetime.strptime(x, '%B %Y').strftime('%y %m'))
up_miles_traveled_data['accident_year_and_month'] = up_miles_traveled_data['accident_year_and_month'].str.replace(r'\b0', '')
up_miles_traveled_data
# Out:
#     Display Year Month of Combined Date      Measure Names  Measure Values  \
# 0           2017          December 2017  Total Train Miles        12350077
# 1           2017          November 2017  Total Train Miles        12326967
# 2           2017           October 2017  Total Train Miles        13277725
# 3           2017         September 2017  Total Train Miles        12513499
# 4           2017            August 2017  Total Train Miles        13020309
# ..           ...                    ...                ...             ...
# 67          2022               May 2022  Total Train Miles         9686706
# 68          2022             April 2022  Total Train Miles         9346652
# 69          2022             March 2022  Total Train Miles         9864030
# 70          2022          February 2022  Total Train Miles         8978280
# 71          2022           January 2022  Total Train Miles         9735127
#
#    accident_year_and_month
# 0                    17 12
# 1                    17 11
# 2                    17 10
# 3                     17 9
# 4                     17 8
# ..                     ...
# 67                    22 5
# 68                    22 4
# 69                    22 3
# 70                    22 2
# 71                    22 1
#
# [72 rows x 5 columns]

# %%
up_df = union_pacific_df.merge(up_miles_traveled_data, left_on='accident_year_and_month', right_on='accident_year_and_month')
up_df['Measure Values'] = up_df['Measure Values'] / 1000000
up_df['accidents_per_million_miles_traveled'] = up_df['tally'] / up_df['Measure Values']
len(up_df)
# Out:
# 72

# %%
ns_df = accidents_df[accidents_df['railroad'] == 'Norfolk Southern Railway Company']
ns_df['tally'] = ns_df.groupby("accident_year_and_month")['Reporting Railroad Code'].transform('count')
ns_df = ns_df.drop_duplicates(subset=['accident_year_and_month', 'tally'])
ns_df
# Out:
#      Reporting Railroad Code           Reporting Railroad Name  Report Year  \
# 0                         NS  Norfolk Southern Railway Company         2022
# 18                        NS  Norfolk Southern Railway Company         2022
# 19                        NS  Norfolk Southern Railway Company         2022
# 26                        NS  Norfolk Southern Railway Company         2022
# 67                        NS  Norfolk Southern Railway Company         2017
# ...                      ...                               ...          ...
# 4500                      NS  Norfolk Southern Railway Company         2018
# 4502                      NS  Norfolk Southern Railway Company         2018
# 4515                      NS  Norfolk Southern Railway Company         2018
# 4563                      NS  Norfolk Southern Railway Company         2018
# 4590                      NS  Norfolk Southern Railway Company         2018
#
#       Accident Year  Accident Month Accident Type  \
# 0                22               7    Derailment
# 18               22               2    Derailment
# 19               22               3    Derailment
# 26               22               1    Derailment
# 67               17               5    Derailment
# ...             ...             ...           ...
# 4500             18               1    Derailment
# 4502             18               2    Derailment
# 4515             18              11    Derailment
# 4563             18               4    Derailment
# 4590             18               8    Derailment
#
#                               railroad accident_year_and_month  tally
# 0     Norfolk Southern Railway Company                    22 7     12
# 18    Norfolk Southern Railway Company                    22 2      9
# 19    Norfolk Southern Railway Company                    22 3     14
# 26    Norfolk Southern Railway Company                    22 1     12
# 67    Norfolk Southern Railway Company                    17 5     23
# ...                                ...                     ...    ...
# 4500  Norfolk Southern Railway Company                    18 1     25
# 4502  Norfolk Southern Railway Company                    18 2     16
# 4515  Norfolk Southern Railway Company                   18 11     15
# 4563  Norfolk Southern Railway Company                    18 4     13
# 4590  Norfolk Southern Railway Company                    18 8     14
#
# [72 rows x 9 columns]

# %%
ns_miles_traveled_data = pd.read_csv('norfolk_southern_traveled.csv')
ns_miles_traveled_data.head()
ns_miles_traveled_data['accident_year_and_month'] = ns_miles_traveled_data['Month of Combined Date'].apply(lambda x: datetime.strptime(x, '%B %Y').strftime('%y %m'))
ns_miles_traveled_data['accident_year_and_month'] = ns_miles_traveled_data['accident_year_and_month'].str.replace(r'\b0', '')
ns_miles_traveled_data.head()
# Out:
#    Display Year Month of Combined Date      Measure Names  Measure Values  \
# 0          2017          December 2017  Total Train Miles         7294007
# 1          2017          November 2017  Total Train Miles         7420478
# 2          2017           October 2017  Total Train Miles         7751247
# 3          2017         September 2017  Total Train Miles         7356282
# 4          2017            August 2017  Total Train Miles         7811337
#
#   accident_year_and_month
# 0                   17 12
# 1                   17 11
# 2                   17 10
# 3                    17 9
# 4                    17 8

# %%
ns_df = ns_df.merge(ns_miles_traveled_data, left_on='accident_year_and_month', right_on='accident_year_and_month')
ns_df['Measure Values'] = ns_df['Measure Values'] / 1000000
ns_df['accidents_per_million_miles_traveled'] = ns_df['tally'] / ns_df['Measure Values']
len(ns_df)
# Out:
# 72

# %%
csx_df = accidents_df[accidents_df['railroad'] == 'CSX Transportation']
csx_df['tally'] = csx_df.groupby("accident_year_and_month")['Reporting Railroad Code'].transform('count')
csx_df = csx_df.drop_duplicates(subset=['accident_year_and_month', 'tally'])
csx_df
# Out:
#      Reporting Railroad Code Reporting Railroad Name  Report Year  \
# 1                        CSX      CSX Transportation         2017
# 49                       CSX      CSX Transportation         2017
# 73                       CSX      CSX Transportation         2022
# 77                       CSX      CSX Transportation         2022
# 79                       CSX      CSX Transportation         2022
# ...                      ...                     ...          ...
# 4595                     CSX      CSX Transportation         2018
# 4597                     CSX      CSX Transportation         2018
# 4599                     CSX      CSX Transportation         2018
# 4612                     CSX      CSX Transportation         2018
# 4613                     CSX      CSX Transportation         2018
#
#       Accident Year  Accident Month Accident Type            railroad  \
# 1                17              12    Derailment  CSX Transportation
# 49               17               1    Derailment  CSX Transportation
# 73               22               1    Derailment  CSX Transportation
# 77               22              10    Derailment  CSX Transportation
# 79               22              11    Derailment  CSX Transportation
# ...             ...             ...           ...                 ...
# 4595             18              10    Derailment  CSX Transportation
# 4597             18              12    Derailment  CSX Transportation
# 4599             18               6    Derailment  CSX Transportation
# 4612             18               4    Derailment  CSX Transportation
# 4613             18               5    Derailment  CSX Transportation
#
#      accident_year_and_month  tally
# 1                      17 12     13
# 49                      17 1     13
# 73                      22 1     10
# 77                     22 10     13
# 79                     22 11     15
# ...                      ...    ...
# 4595                   18 10     13
# 4597                   18 12      9
# 4599                    18 6     17
# 4612                    18 4     19
# 4613                    18 5     18
#
# [72 rows x 9 columns]

# %%
csx_miles_traveled_data = pd.read_csv('csx_traveled.csv')
csx_miles_traveled_data.head()
csx_miles_traveled_data['accident_year_and_month'] = csx_miles_traveled_data['Month of Combined Date'].apply(lambda x: datetime.strptime(x, '%B %Y').strftime('%y %m'))
csx_miles_traveled_data['accident_year_and_month'] = csx_miles_traveled_data['accident_year_and_month'].str.replace(r'\b0', '')
csx_miles_traveled_data.head()
# Out:
#    Display Year Month of Combined Date      Measure Names  Measure Values  \
# 0          2017          December 2017  Total Train Miles         6233531
# 1          2017          November 2017  Total Train Miles         6225892
# 2          2017           October 2017  Total Train Miles         6578685
# 3          2017         September 2017  Total Train Miles         6157209
# 4          2017            August 2017  Total Train Miles         6450223
#
#   accident_year_and_month
# 0                   17 12
# 1                   17 11
# 2                   17 10
# 3                    17 9
# 4                    17 8

# %%
csx_df = csx_df.merge(csx_miles_traveled_data, left_on='accident_year_and_month', right_on='accident_year_and_month')
csx_df['Measure Values'] = csx_df['Measure Values'] / 1000000
csx_df['accidents_per_million_miles_traveled'] = csx_df['tally'] / csx_df['Measure Values']
len(csx_df)
# Out:
# 72

# %%
canadian_nat_df = accidents_df[accidents_df['railroad'] == 'Canadian National - North America']
canadian_nat_df['tally'] = canadian_nat_df.groupby("accident_year_and_month")['Reporting Railroad Code'].transform('count')
canadian_nat_df = canadian_nat_df.drop_duplicates(subset=['accident_year_and_month', 'tally'])
canadian_nat_df
# Out:
#      Reporting Railroad Code                      Reporting Railroad Name  \
# 7                         CC  Chicago, Central & Pacific Railroad Company
# 24                        IC            Illinois Central Railroad Company
# 62                        CC  Chicago, Central & Pacific Railroad Company
# 98                        IC            Illinois Central Railroad Company
# 132                       WC                       WISCONSIN CENTRAL LTD.
# ...                      ...                                          ...
# 4761                      WC                       WISCONSIN CENTRAL LTD.
# 4767                      WC                       WISCONSIN CENTRAL LTD.
# 4768                      WC                       WISCONSIN CENTRAL LTD.
# 4930                     GTW            GRAND TRUNK WESTERN RAILROAD INC.
# 5134                      IC            Illinois Central Railroad Company
#
#       Report Year  Accident Year  Accident Month Accident Type  \
# 7            2017             17               8    Derailment
# 24           2022             22               8    Derailment
# 62           2022             22               6    Derailment
# 98           2017             17               1    Derailment
# 132          2017             17               6    Derailment
# ...           ...            ...             ...           ...
# 4761         2018             18               7    Derailment
# 4767         2018             18               8    Derailment
# 4768         2018             18               9    Derailment
# 4930         2018             18               4    Derailment
# 5134         2018             18               6    Derailment
#
#                                railroad accident_year_and_month  tally
# 7     Canadian National - North America                    17 8      4
# 24    Canadian National - North America                    22 8      1
# 62    Canadian National - North America                    22 6      4
# 98    Canadian National - North America                    17 1      3
# 132   Canadian National - North America                    17 6      7
# ...                                 ...                     ...    ...
# 4761  Canadian National - North America                    18 7      3
# 4767  Canadian National - North America                    18 8      2
# 4768  Canadian National - North America                    18 9      2
# 4930  Canadian National - North America                    18 4      4
# 5134  Canadian National - North America                    18 6      3
#
# [65 rows x 9 columns]

# %%
canadiannat_miles_traveled_data = pd.read_csv('canadian_nat.csv')
canadiannat_miles_traveled_data['accident_year_and_month'] = canadiannat_miles_traveled_data['Month of Combined Date'].apply(lambda x: datetime.strptime(x, '%B %Y').strftime('%y %m'))
canadiannat_miles_traveled_data['accident_year_and_month'] = canadiannat_miles_traveled_data['accident_year_and_month'].str.replace(r'\b0', '')
canadiannat_miles_traveled_data.head()
# Out:
#    Display Year Month of Combined Date      Measure Names  Measure Values  \
# 0          2017          December 2017  Total Train Miles         1622029
# 1          2017          November 2017  Total Train Miles         1647793
# 2          2017           October 2017  Total Train Miles         1702978
# 3          2017         September 2017  Total Train Miles         1617992
# 4          2017            August 2017  Total Train Miles         1637586
#
#   accident_year_and_month
# 0                   17 12
# 1                   17 11
# 2                   17 10
# 3                    17 9
# 4                    17 8

# %%
canadian_nat = canadian_nat_df.merge(canadiannat_miles_traveled_data, left_on='accident_year_and_month', right_on='accident_year_and_month')
canadian_nat['Measure Values'] = canadian_nat['Measure Values'] / 1000000
canadian_nat['accidents_per_million_miles_traveled'] = canadian_nat['tally'] / canadian_nat['Measure Values']
len(canadian_nat)
# Out:
# 65

# %%
kansas_df = accidents_df[accidents_df['railroad'] == 'Kansas City Southern Railway Company']
kansas_df['tally'] = kansas_df.groupby("accident_year_and_month")['Reporting Railroad Code'].transform('count')
kansas_df = kansas_df.drop_duplicates(subset=['accident_year_and_month', 'tally'])
kansas_df
# Out:
#      Reporting Railroad Code               Reporting Railroad Name  \
# 25                       KCS  Kansas City Southern Railway Company
# 123                      KCS  Kansas City Southern Railway Company
# 147                      KCS  Kansas City Southern Railway Company
# 218                      KCS  Kansas City Southern Railway Company
# 433                      KCS  Kansas City Southern Railway Company
# ...                      ...                                   ...
# 5143                     KCS  Kansas City Southern Railway Company
# 5369                     KCS  Kansas City Southern Railway Company
# 5457                     KCS  Kansas City Southern Railway Company
# 5471                     KCS  Kansas City Southern Railway Company
# 5642                     KCS  Kansas City Southern Railway Company
#
#       Report Year  Accident Year  Accident Month Accident Type  \
# 25           2022             22               1    Derailment
# 123          2017             17              11    Derailment
# 147          2022             22               5    Derailment
# 218          2022             22               2    Derailment
# 433          2022             22               7    Derailment
# ...           ...            ...             ...           ...
# 5143         2018             18              11    Derailment
# 5369         2018             18               7    Derailment
# 5457         2018             18               3    Derailment
# 5471         2018             18               1    Derailment
# 5642         2017             17               3    Derailment
#
#                                   railroad accident_year_and_month  tally
# 25    Kansas City Southern Railway Company                    22 1      3
# 123   Kansas City Southern Railway Company                   17 11      2
# 147   Kansas City Southern Railway Company                    22 5      4
# 218   Kansas City Southern Railway Company                    22 2      1
# 433   Kansas City Southern Railway Company                    22 7      1
# ...                                    ...                     ...    ...
# 5143  Kansas City Southern Railway Company                   18 11      1
# 5369  Kansas City Southern Railway Company                    18 7      3
# 5457  Kansas City Southern Railway Company                    18 3      1
# 5471  Kansas City Southern Railway Company                    18 1      2
# 5642  Kansas City Southern Railway Company                    17 3      1
#
# [61 rows x 9 columns]

# %%
kansas_miles_traveled_data = pd.read_csv('kansas_traveled_miles.csv')
kansas_miles_traveled_data.head()
kansas_miles_traveled_data['accident_year_and_month'] = kansas_miles_traveled_data['Month of Combined Date'].apply(lambda x: datetime.strptime(x, '%B %Y').strftime('%y %m'))
kansas_miles_traveled_data['accident_year_and_month'] = kansas_miles_traveled_data['accident_year_and_month'].str.replace(r'\b0', '')
kansas_miles_traveled_data.head()
# Out:
#    Display Year Month of Combined Date      Measure Names  Measure Values  \
# 0          2017          December 2017  Total Train Miles          858842
# 1          2017          November 2017  Total Train Miles          899282
# 2          2017           October 2017  Total Train Miles          963114
# 3          2017         September 2017  Total Train Miles          918743
# 4          2017            August 2017  Total Train Miles          937142
#
#   accident_year_and_month
# 0                   17 12
# 1                   17 11
# 2                   17 10
# 3                    17 9
# 4                    17 8

# %%
kansas_df = kansas_df.merge(kansas_miles_traveled_data, left_on='accident_year_and_month', right_on='accident_year_and_month')
kansas_df ['Measure Values'] = kansas_df ['Measure Values'] / 1000000
kansas_df ['accidents_per_million_miles_traveled'] = kansas_df ['tally'] /kansas_df ['Measure Values']
len(kansas_df)
# Out:
# 61

# %%
kansas_df.head()
# Out:
#   Reporting Railroad Code               Reporting Railroad Name  Report Year  \
# 0                     KCS  Kansas City Southern Railway Company         2022
# 1                     KCS  Kansas City Southern Railway Company         2017
# 2                     KCS  Kansas City Southern Railway Company         2022
# 3                     KCS  Kansas City Southern Railway Company         2022
# 4                     KCS  Kansas City Southern Railway Company         2022
#
#    Accident Year  Accident Month Accident Type  \
# 0             22               1    Derailment
# 1             17              11    Derailment
# 2             22               5    Derailment
# 3             22               2    Derailment
# 4             22               7    Derailment
#
#                                railroad accident_year_and_month  tally  \
# 0  Kansas City Southern Railway Company                    22 1      3
# 1  Kansas City Southern Railway Company                   17 11      2
# 2  Kansas City Southern Railway Company                    22 5      4
# 3  Kansas City Southern Railway Company                    22 2      1
# 4  Kansas City Southern Railway Company                    22 7      1
#
#    Display Year Month of Combined Date      Measure Names  Measure Values  \
# 0          2022           January 2022  Total Train Miles        0.874657
# 1          2017          November 2017  Total Train Miles        0.899282
# 2          2022               May 2022  Total Train Miles        0.856300
# 3          2022          February 2022  Total Train Miles        0.837206
# 4          2022              July 2022  Total Train Miles        0.872991
#
#    accidents_per_million_miles_traveled
# 0                              3.429916
# 1                              2.223996
# 2                              4.671260
# 3                              1.194449
# 4                              1.145487

# %%
can_pacific_df = accidents_df[accidents_df['railroad'] == 'Canadian Pacific Railway Company']
can_pacific_df['tally'] = can_pacific_df.groupby("accident_year_and_month")['Reporting Railroad Code'].transform('count')
can_pacific_df = can_pacific_df.drop_duplicates(subset=['accident_year_and_month', 'tally'])
can_pacific_df.head()
# Out:
#     Reporting Railroad Code           Reporting Railroad Name  Report Year  \
# 6                        CP  Canadian Pacific Railway Company         2017
# 70                       CP  Canadian Pacific Railway Company         2022
# 72                       CP  Canadian Pacific Railway Company         2022
# 126                      CP  Canadian Pacific Railway Company         2017
# 141                      CP  Canadian Pacific Railway Company         2022
#
#      Accident Year  Accident Month Accident Type  \
# 6               17               8    Derailment
# 70              22              10    Derailment
# 72              22               6    Derailment
# 126             17              11    Derailment
# 141             22               3    Derailment
#
#                              railroad accident_year_and_month  tally
# 6    Canadian Pacific Railway Company                    17 8      1
# 70   Canadian Pacific Railway Company                   22 10      2
# 72   Canadian Pacific Railway Company                    22 6      2
# 126  Canadian Pacific Railway Company                   17 11      2
# 141  Canadian Pacific Railway Company                    22 3      2

# %%
can_pacific_traveled_data = pd.read_csv('can_pac_miles.csv')
can_pacific_traveled_data['accident_year_and_month'] = can_pacific_traveled_data['Month of Combined Date'].apply(lambda x: datetime.strptime(x, '%B %Y').strftime('%y %m'))
can_pacific_traveled_data['accident_year_and_month'] = can_pacific_traveled_data['accident_year_and_month'].str.replace(r'\b0', '')
can_pacific_traveled_data.head()
# Out:
#    Display Year Month of Combined Date      Measure Names  Measure Values  \
# 0          2017          December 2017  Total Train Miles          738110
# 1          2017          November 2017  Total Train Miles          745924
# 2          2017           October 2017  Total Train Miles          745597
# 3          2017         September 2017  Total Train Miles          731635
# 4          2017            August 2017  Total Train Miles          716405
#
#   accident_year_and_month
# 0                   17 12
# 1                   17 11
# 2                   17 10
# 3                    17 9
# 4                    17 8

# %%
can_pac_df = can_pacific_df.merge(can_pacific_traveled_data, left_on='accident_year_and_month', right_on='accident_year_and_month')
can_pac_df ['Measure Values'] = can_pac_df['Measure Values'] / 1000000
can_pac_df ['accidents_per_million_miles_traveled'] = can_pac_df['tally'] /can_pac_df['Measure Values']
len(can_pac_df)
can_pac_df.head()
# Out:
#   Reporting Railroad Code           Reporting Railroad Name  Report Year  \
# 0                      CP  Canadian Pacific Railway Company         2017
# 1                      CP  Canadian Pacific Railway Company         2022
# 2                      CP  Canadian Pacific Railway Company         2022
# 3                      CP  Canadian Pacific Railway Company         2017
# 4                      CP  Canadian Pacific Railway Company         2022
#
#    Accident Year  Accident Month Accident Type  \
# 0             17               8    Derailment
# 1             22              10    Derailment
# 2             22               6    Derailment
# 3             17              11    Derailment
# 4             22               3    Derailment
#
#                            railroad accident_year_and_month  tally  \
# 0  Canadian Pacific Railway Company                    17 8      1
# 1  Canadian Pacific Railway Company                   22 10      2
# 2  Canadian Pacific Railway Company                    22 6      2
# 3  Canadian Pacific Railway Company                   17 11      2
# 4  Canadian Pacific Railway Company                    22 3      2
#
#    Display Year Month of Combined Date      Measure Names  Measure Values  \
# 0          2017            August 2017  Total Train Miles        0.716405
# 1          2022           October 2022  Total Train Miles        0.753076
# 2          2022              June 2022  Total Train Miles        0.727349
# 3          2017          November 2017  Total Train Miles        0.745924
# 4          2022             March 2022  Total Train Miles        0.767527
#
#    accidents_per_million_miles_traveled
# 0                              1.395858
# 1                              2.655774
# 2                              2.749712
# 3                              2.681238
# 4                              2.605772

# %%
kansas_df = kansas_df[['railroad', 'accident_year_and_month', 'accidents_per_million_miles_traveled']]
can_pac_df = can_pac_df[['railroad', 'accident_year_and_month', 'accidents_per_million_miles_traveled']]
canadian_nat = canadian_nat[['railroad', 'accident_year_and_month', 'accidents_per_million_miles_traveled']]
csx_df = csx_df[['railroad', 'accident_year_and_month', 'accidents_per_million_miles_traveled']]
ns_df = ns_df[['railroad', 'accident_year_and_month', 'accidents_per_million_miles_traveled']]
up_df= up_df[['railroad', 'accident_year_and_month', 'accidents_per_million_miles_traveled']]
bnsf_df = bnsf_df[['railroad', 'accident_year_and_month', 'accidents_per_million_miles_traveled']]
# concatenate the dataframes vertically
merged_df = pd.concat([kansas_df, can_pac_df,canadian_nat,csx_df,ns_df,up_df,bnsf_df], ignore_index=True)
merged_df.to_csv('railways_accident_rate')

# %%
accidents_df['railroad'].value_counts()
# Out:
# Union Pacific Railroad Company          2024
# BNSF Railway Company                    1536
# Norfolk Southern Railway Company         946
# CSX Transportation                       812
# Canadian National - North America        169
# Kansas City Southern Railway Company     146
# Canadian Pacific Railway Company          34
# Name: railroad, dtype: int64

# %%
accidents_df.groupby('Reporting Parent Railroad Company Name').accident_year_and_month.value_counts()

# %%
accidents_df.accident_year_and_month.value_counts(ascending=False)
# Out:
# 19 8     216
# 19 1     209
# 18 1     194
# 18 8     192
# 18 5     192
# 18 10    184
# 18 7     182
# 19 10    180
# 19 7     177
# 18 6     177
# 20 7     176
# 19 3     172
# 18 9     172
# 18 4     171
# 20 12    170
# 19 4     169
# 21 10    169
# 18 11    167
# 20 8     164
# 19 2     164
# 22 8     163
# 22 12    163
# 22 1     162
# 22 3     162
# 22 7     162
# 19 9     159
# 18 3     159
# 21 7     159
# 22 9     158
# 21 8     157
# 19 6     157
# 21 9     153
# 18 12    152
# 21 6     151
# 22 10    151
# 19 5     149
# 21 3     149
# 19 11    148
# 21 12    147
# 20 2     146
# 20 11    145
# 20 3     145
# 22 11    145
# 18 2     144
# 20 6     143
# 21 11    143
# 22 5     141
# 22 6     140
# 19 12    140
# 20 1     139
# 22 4     139
# 22 2     139
# 20 10    138
# 20 9     138
# 21 2     136
# 20 5     133
# 21 1     133
# 20 4     130
# 21 4     126
# 21 5     120
# Name: accident_year_and_month, dtype: int64

# %%
stacked_bar_accidents_df = accidents_df.groupby('Reporting Parent Railroad Company Name').accident_year_and_month.value_counts()
stacked_bar_accidents_df.to_csv('stacked_bar_accidents_df')

# %%
stacked_bar_accidents_df
# Out:
# Reporting Parent Railroad Company Name  accident_year_and_month
# BNSF Railway Company                    19 10                      54
#                                         18 9                       52
#                                         19 8                       50
#                                         19 1                       49
#                                         18 7                       46
#                                                                    ..
# Union Pacific Railroad Company          20 1                       45
#                                         21 4                       45
#                                         20 6                       43
#                                         20 11                      41
#                                         22 2                       34
# Name: accident_year_and_month, Length: 393, dtype: int64

# %%
# %%R
#
# # Read data
# stacked_bar_accidents_df <- read_csv('stacked_bar_accidents_df')
# stacked_bar_accidents_df
# Out:
# Rows: 393 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): railroad, accident_year_and_month
# dbl (1): number
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# # A tibble: 393 × 3
#    railroad             accident_year_and_month number
#    <chr>                <chr>                    <dbl>
#  1 BNSF Railway Company 19 10                       54
#  2 BNSF Railway Company 18 9                        52
#  3 BNSF Railway Company 19 8                        50
#  4 BNSF Railway Company 19 1                        49
#  5 BNSF Railway Company 18 7                        46
#  6 BNSF Railway Company 18 1                        44
#  7 BNSF Railway Company 18 10                       43
#  8 BNSF Railway Company 22 12                       43
#  9 BNSF Railway Company 22 2                        43
# 10 BNSF Railway Company 20 7                        41
# # … with 383 more rows
# # ℹ Use `print(n = ...)` to see more rows

# %%
# %%R
#
# library(ggplot2)

# %%
# %%R -w 1500
# ggplot(stacked_bar_accidents_df) +
#   aes(fill=railroad, y=number, x=accident_year_and_month) +
#   geom_bar(position="stack", stat="identity") +
#   ggtitle("Railroad") +
#   theme_minimal() +
#   geom_text(aes(label=number), position=position_stack(vjust=0.5))

# %%
# %%R -w 1500
#
#
# ggplot(stacked_bar_accidents_df, aes(fill=railroad, y=number, x=accident_year_and_month)) +
#   geom_bar(position="stack", stat="identity") +
#   stat_summary(aes(label=..y..), fun=sum, geom="text", position=position_stack(vjust=0.5)) +
#   ggtitle("Railroad") +
#   theme_minimal()

# %%
stacked_bar_accidents_df_2 = accidents_df.groupby('Reporting Parent Railroad Company Name')['Report Year'].value_counts()
stacked_bar_accidents_df_2.head()
# Out:
# Reporting Parent Railroad Company Name  Report Year
# BNSF Railway Company                    2018           483
#                                         2019           462
#                                         2022           394
#                                         2020           393
#                                         2021           328
# Name: Report Year, dtype: int64

# %%
stacked_bar_accidents_df_2.to_csv('stacked_bar_accidents_df_2')

# %%
# %%R
#
# # Read data
# stacked_bar_accidents_df_2 <- read_csv('stacked_bar_accidents_df_2')
# stacked_bar_accidents_df_2
# Out:
# Rows: 35 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): railroad
# dbl (2): report_year, number
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# # A tibble: 35 × 3
#    railroad             report_year number
#    <chr>                      <dbl>  <dbl>
#  1 BNSF Railway Company        2018    483
#  2 BNSF Railway Company        2019    462
#  3 BNSF Railway Company        2022    394
#  4 BNSF Railway Company        2020    393
#  5 BNSF Railway Company        2021    328
#  6 CSX Transportation          2018    365
#  7 CSX Transportation          2020    299
#  8 CSX Transportation          2022    290
#  9 CSX Transportation          2021    282
# 10 CSX Transportation          2019    261
# # … with 25 more rows
# # ℹ Use `print(n = ...)` to see more rows

# %%
# %%R -w 1500
# ggplot(stacked_bar_accidents_df_2) +
#   aes(fill=railroad, y=number, x=report_year) +
#   geom_bar(position="stack", stat="identity") +
#   ggtitle("Railroad") +
#   theme_minimal() +
#   geom_text(aes(label=number), position=position_stack(vjust=0.5))

# %%
derailments_df = pd.read_csv('derailments.csv')
derailments_df.head()
# Out:
#   Reporting Railroad Code           Reporting Railroad Name  Report Year  \
# 0                      NS  Norfolk Southern Railway Company         2022
# 1                     CSX                CSX Transportation         2017
# 2                      NS  Norfolk Southern Railway Company         2022
# 3                      UP    Union Pacific Railroad Company         2022
# 4                      UP    Union Pacific Railroad Company         2022
#
#    Accident Year  Accident Month Accident Type  \
# 0             22               7    Derailment
# 1             17              12    Derailment
# 2             22               7    Derailment
# 3             22               2    Derailment
# 4             22              11    Derailment
#
#                            railroad accident_year_and_month
# 0  Norfolk Southern Railway Company                    22 7
# 1                CSX Transportation                   17 12
# 2  Norfolk Southern Railway Company                    22 7
# 3    Union Pacific Railroad Company                    22 2
# 4    Union Pacific Railroad Company                   22 11

# %%
derailments_df.railroad.value_counts()
# Out:
# Union Pacific Railroad Company          2024
# BNSF Railway Company                    1536
# Norfolk Southern Railway Company         946
# CSX Transportation                       812
# Canadian National - North America        169
# Kansas City Southern Railway Company     146
# Canadian Pacific Railway Company          34
# Name: railroad, dtype: int64

# %%
derailments_df_groupby = derailments_df.groupby('railroad').accident_year_and_month.value_counts()
derailments_df_groupby.to_csv('derailments_df_groupby.csv')

# %%
# %%R
#
# # Read data
# derailments_df_groupby <- read_csv('derailments_df_groupby.csv')
# derailments_df_groupby
# Out:
# Rows: 438 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): railroad, accident_year_and_month
# dbl (1): number
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# # A tibble: 438 × 3
#    railroad             accident_year_and_month number
#    <chr>                <chr>                    <dbl>
#  1 BNSF Railway Company 19 1                        39
#  2 BNSF Railway Company 19 10                       33
#  3 BNSF Railway Company 19 8                        32
#  4 BNSF Railway Company 18 1                        31
#  5 BNSF Railway Company 18 7                        31
#  6 BNSF Railway Company 20 1                        30
#  7 BNSF Railway Company 17 8                        28
#  8 BNSF Railway Company 17 7                        27
#  9 BNSF Railway Company 22 12                       27
# 10 BNSF Railway Company 22 7                        27
# # … with 428 more rows
# # ℹ Use `print(n = ...)` to see more rows

# %%
# %%R -w 1500
# ggplot(derailments_df_groupby) +
#   aes(fill=railroad, y=number, x=accident_year_and_month) +
#   geom_bar(position="stack", stat="identity") +
#   ggtitle("derailments") +
#   theme_minimal() +
#   geom_text(aes(label=number), position=position_stack(vjust=0.5))

# %%
derailments_df_groupby_2 = derailments_df.groupby('railroad')['Report Year'].value_counts()
derailments_df_groupby_2
# Out:
# railroad                              Report Year
# BNSF Railway Company                  2019           301
#                                       2018           288
#                                       2017           254
#                                       2020           248
#                                       2022           248
#                                       2021           197
# CSX Transportation                    2018           195
#                                       2017           159
#                                       2021           126
#                                       2022           120
#                                       2020           114
#                                       2019            98
# Canadian National - North America     2021            35
#                                       2018            30
#                                       2019            30
#                                       2022            28
#                                       2017            27
#                                       2020            19
# Canadian Pacific Railway Company      2017             9
#                                       2019             7
#                                       2020             7
#                                       2022             6
#                                       2018             3
#                                       2021             2
# Kansas City Southern Railway Company  2018            34
#                                       2017            28
#                                       2020            25
#                                       2021            22
#                                       2019            20
#                                       2022            17
# Norfolk Southern Railway Company      2017           182
#                                       2018           178
#                                       2019           167
#                                       2021           158
#                                       2020           146
#                                       2022           115
# Union Pacific Railroad Company        2019           410
#                                       2018           355
#                                       2022           339
#                                       2017           331
#                                       2021           299
#                                       2020           290
# Name: Report Year, dtype: int64

# %%
# Group by railroad and year and count the number of derailments
derailments_df_groupby_2 = derailments_df.groupby(['railroad', 'Report Year']).size().reset_index(name='count')

# Group by railroad and calculate the mean number of derailments per year
avg_by_railroad = derailments_df_groupby_2.groupby('railroad')['count'].mean().reset_index(name='avg_count')

# Append the average number of derailments per year for each railroad to the original dataframe
derailments_df_groupby_2 = pd.merge(derailments_df_groupby_2, avg_by_railroad, on='railroad')

# Print the updated dataframe
print(derailments_df_groupby_2)
# Out:
#                                 railroad  Report Year  count   avg_count
# 0                   BNSF Railway Company         2017    254  256.000000
# 1                   BNSF Railway Company         2018    288  256.000000
# 2                   BNSF Railway Company         2019    301  256.000000
# 3                   BNSF Railway Company         2020    248  256.000000
# 4                   BNSF Railway Company         2021    197  256.000000
# 5                   BNSF Railway Company         2022    248  256.000000
# 6                     CSX Transportation         2017    159  135.333333
# 7                     CSX Transportation         2018    195  135.333333
# 8                     CSX Transportation         2019     98  135.333333
# 9                     CSX Transportation         2020    114  135.333333
# 10                    CSX Transportation         2021    126  135.333333
# 11                    CSX Transportation         2022    120  135.333333
# 12     Canadian National - North America         2017     27   28.166667
# 13     Canadian National - North America         2018     30   28.166667
# 14     Canadian National - North America         2019     30   28.166667
# 15     Canadian National - North America         2020     19   28.166667
# 16     Canadian National - North America         2021     35   28.166667
# 17     Canadian National - North America         2022     28   28.166667
# 18      Canadian Pacific Railway Company         2017      9    5.666667
# 19      Canadian Pacific Railway Company         2018      3    5.666667
# 20      Canadian Pacific Railway Company         2019      7    5.666667
# 21      Canadian Pacific Railway Company         2020      7    5.666667
# 22      Canadian Pacific Railway Company         2021      2    5.666667
# 23      Canadian Pacific Railway Company         2022      6    5.666667
# 24  Kansas City Southern Railway Company         2017     28   24.333333
# 25  Kansas City Southern Railway Company         2018     34   24.333333
# 26  Kansas City Southern Railway Company         2019     20   24.333333
# 27  Kansas City Southern Railway Company         2020     25   24.333333
# 28  Kansas City Southern Railway Company         2021     22   24.333333
# 29  Kansas City Southern Railway Company         2022     17   24.333333
# 30      Norfolk Southern Railway Company         2017    182  157.666667
# 31      Norfolk Southern Railway Company         2018    178  157.666667
# 32      Norfolk Southern Railway Company         2019    167  157.666667
# 33      Norfolk Southern Railway Company         2020    146  157.666667
# 34      Norfolk Southern Railway Company         2021    158  157.666667
# 35      Norfolk Southern Railway Company         2022    115  157.666667
# 36        Union Pacific Railroad Company         2017    331  337.333333
# 37        Union Pacific Railroad Company         2018    355  337.333333
# 38        Union Pacific Railroad Company         2019    410  337.333333
# 39        Union Pacific Railroad Company         2020    290  337.333333
# 40        Union Pacific Railroad Company         2021    299  337.333333
# 41        Union Pacific Railroad Company         2022    339  337.333333

# %%
derailments_df_groupby_2.to_csv('derailments_df_groupby_2')

# %%
# %%R
# # Read data
# derailments_df_groupby_2 <- read_csv('derailments_df_groupby_2')
# derailments_df_groupby_2
# Out:
# Rows: 42 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): railroad
# dbl (2): Report Year, number
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# # A tibble: 42 × 3
#    railroad             `Report Year` number
#    <chr>                        <dbl>  <dbl>
#  1 BNSF Railway Company          2019    301
#  2 BNSF Railway Company          2018    288
#  3 BNSF Railway Company          2017    254
#  4 BNSF Railway Company          2020    248
#  5 BNSF Railway Company          2022    248
#  6 BNSF Railway Company          2021    197
#  7 CSX Transportation            2018    195
#  8 CSX Transportation            2017    159
#  9 CSX Transportation            2021    126
# 10 CSX Transportation            2022    120
# # … with 32 more rows
# # ℹ Use `print(n = ...)` to see more rows

# %%
# %%R -w 1500
# ggplot(derailments_df_groupby_2) +
#   aes(fill=railroad, y=number, x=`Report Year`) +
#   geom_bar(position="stack", stat="identity") +
#   ggtitle("derailment") +
#   theme_minimal() +
#   geom_text(aes(label=number), position=position_stack(vjust=0.5))

# %%
# %%R
# # Read data
# railways_accident_rate <- read_csv('railways_accident_rate')
# railways_accident_rate
# Out:
# New names:
# • `` -> `...1`
# Rows: 438 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): railroad, accident_year_and_month
# dbl (2): ...1, accidents_per_million_miles_traveled
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# # A tibble: 438 × 4
#     ...1 railroad                             accident_year_and_month accident…¹
#    <dbl> <chr>                                <chr>                        <dbl>
#  1     0 Kansas City Southern Railway Company 22 1                          3.43
#  2     1 Kansas City Southern Railway Company 17 11                         2.22
#  3     2 Kansas City Southern Railway Company 22 5                          4.67
#  4     3 Kansas City Southern Railway Company 22 2                          1.19
#  5     4 Kansas City Southern Railway Company 22 7                          1.15
#  6     5 Kansas City Southern Railway Company 22 4                          1.20
#  7     6 Kansas City Southern Railway Company 22 8                          2.25
#  8     7 Kansas City Southern Railway Company 22 11                         1.12
#  9     8 Kansas City Southern Railway Company 22 9                          3.39
# 10     9 Kansas City Southern Railway Company 17 12                         4.66
# # … with 428 more rows, and abbreviated variable name
# #   ¹​accidents_per_million_miles_traveled
# # ℹ Use `print(n = ...)` to see more rows

# %%
railways_accident_rate = pd.read_csv('railways_accident_rate')
railways_accident_rate.head()
# Out:
#    Unnamed: 0                              railroad accident_year_and_month  \
# 0           0  Kansas City Southern Railway Company                    22 1
# 1           1  Kansas City Southern Railway Company                   17 11
# 2           2  Kansas City Southern Railway Company                    22 5
# 3           3  Kansas City Southern Railway Company                    22 2
# 4           4  Kansas City Southern Railway Company                    22 7
#
#    accidents_per_million_miles_traveled
# 0                              3.429916
# 1                              2.223996
# 2                              4.671260
# 3                              1.194449
# 4                              1.145487

# %%
avg_accidents = railways_accident_rate.groupby('accident_year_and_month').mean()
avg_accidents
# Out:
#                          Unnamed: 0  accidents_per_million_miles_traveled
# accident_year_and_month
# 17 1                     181.142857                              1.825875
# 17 10                    208.333333                              1.596857
# 17 11                    177.285714                              1.980212
# 17 12                    198.666667                              2.153475
# 17 2                     200.333333                              2.059212
# ...                             ...                                   ...
# 22 5                     194.333333                              2.157721
# 22 6                     203.166667                              2.419318
# 22 7                     195.333333                              2.006805
# 22 8                     196.833333                              1.686717
# 22 9                     196.000000                              2.174880
#
# [72 rows x 2 columns]

# %%
# %%R -w 2000
#
# ggplot(data = railways_accident_rate, aes(x = accident_year_and_month, y = accidents_per_million_miles_traveled, group = railroad, color = railroad)) +
#   geom_line() +
#   labs(x = "Accident Year and Month", y = "Accidents per Million Miles Traveled", title = "Railroad Accidents")

# %%
# %%R
#
# library(dplyr)
#
# # Group the data by accident_year_and_month and calculate the mean accidents_per_million_miles_traveled for each month
# avg_accidents <- railways_accident_rate %>%
#   group_by(accident_year_and_month) %>%
#   summarize(mean_accidents = mean(accidents_per_million_miles_traveled)) %>%
#   arrange(desc(accident_year_and_month))
#
# print(avg_accidents, n = Inf)
# Out:
# # A tibble: 72 × 2
#    accident_year_and_month mean_accidents
#    <chr>                            <dbl>
#  1 22 9                              2.17
#  2 22 8                              1.69
#  3 22 7                              2.01
#  4 22 6                              2.42
#  5 22 5                              2.16
#  6 22 4                              1.53
#  7 22 3                              2.04
#  8 22 2                              1.69
#  9 22 12                             2.16
# 10 22 11                             1.93
# 11 22 10                             1.89
# 12 22 1                              2.26
# 13 21 9                              2.55
# 14 21 8                              2.23
# 15 21 7                              2.42
# 16 21 6                              2.29
# 17 21 5                              1.95
# 18 21 4                              1.57
# 19 21 3                              1.82
# 20 21 2                              2.52
# 21 21 12                             2.23
# 22 21 11                             2.47
# 23 21 10                             1.56
# 24 21 1                              1.81
# 25 20 9                              1.97
# 26 20 8                              2.47
# 27 20 7                              2.26
# 28 20 6                              2.18
# 29 20 5                              1.62
# 30 20 4                              2.90
# 31 20 3                              1.59
# 32 20 2                              2.17
# 33 20 12                             2.37
# 34 20 11                             1.62
# 35 20 10                             1.99
# 36 20 1                              1.78
# 37 19 9                              1.68
# 38 19 8                              2.15
# 39 19 7                              1.89
# 40 19 6                              1.63
# 41 19 5                              1.97
# 42 19 4                              1.74
# 43 19 3                              2.15
# 44 19 2                              1.92
# 45 19 12                             2.46
# 46 19 11                             1.63
# 47 19 10                             1.86
# 48 19 1                              2.03
# 49 18 9                              1.86
# 50 18 8                              1.98
# 51 18 7                              2.40
# 52 18 6                              2.29
# 53 18 5                              2.77
# 54 18 4                              2.60
# 55 18 3                              1.59
# 56 18 2                              1.98
# 57 18 12                             2.51
# 58 18 11                             2.02
# 59 18 10                             2.03
# 60 18 1                              2.80
# 61 17 9                              1.72
# 62 17 8                              1.88
# 63 17 7                              2.59
# 64 17 6                              3.20
# 65 17 5                              1.52
# 66 17 4                              1.41
# 67 17 3                              1.88
# 68 17 2                              2.06
# 69 17 12                             2.15
# 70 17 11                             1.98
# 71 17 10                             1.60
# 72 17 1                              1.83
